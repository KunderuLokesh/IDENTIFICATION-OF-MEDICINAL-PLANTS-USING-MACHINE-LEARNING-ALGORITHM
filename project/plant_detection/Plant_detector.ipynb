# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
training_set = train_datagen.flow_from_directory('Dataset/train',
                                                 target_size=(128, 128),
                                                 batch_size=32,
                                                 class_mode='categorical')  # Use 'categorical' for multiple classes
# Out:
# Found 52 images belonging to 4 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory('Dataset/test',
                                            target_size=(128, 128),
                                            batch_size=34,
                                            class_mode='categorical')  # Use 'categorical' for multiple classes
# Out:
# Found 12 images belonging to 4 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=50, kernel_size=3, activation='relu', input_shape=[128, 128, 3]))
# Out:
# c:\Users\lokes\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=60, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
#cnn.add(tf.keras.layers.Dense(units=64, activation='relu'))

# %%
#cnn.add(tf.keras.layers.Dense(units=90, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
num_plant_classes = 4  # Change this to the number of plant classes
cnn.add(tf.keras.layers.Dense(units=num_plant_classes, activation='softmax'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
from keras.optimizers import Adam  

learning_rate = 0.001  
optimizer = Adam(learning_rate=learning_rate)

# %%
cnn.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 834ms/step - accuracy: 1.0000 - loss: 0.0282 - val_accuracy: 0.6667 - val_loss: 0.7547
# Epoch 2/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.6667 - val_loss: 1.3128
# Epoch 3/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - accuracy: 0.9872 - loss: 0.0366 - val_accuracy: 0.7500 - val_loss: 0.8740
# Epoch 4/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - accuracy: 0.9744 - loss: 0.0848 - val_accuracy: 0.6667 - val_loss: 1.3934
# Epoch 5/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.6667 - val_loss: 1.3478
# Epoch 6/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.5833 - val_loss: 2.2192
# Epoch 7/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 0.9872 - loss: 0.0814 - val_accuracy: 0.8333 - val_loss: 0.8458
# Epoch 8/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step - accuracy: 1.0000 - loss: 0.0218 - val_accuracy: 0.9167 - val_loss: 1.1217
# Epoch 9/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - accuracy: 0.9535 - loss: 0.1729 - val_accuracy: 0.7500 - val_loss: 1.0946
# Epoch 10/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 426ms/step - accuracy: 0.9872 - loss: 0.0821 - val_accuracy: 0.5000 - val_loss: 1.0811
# Epoch 11/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 0.5833 - val_loss: 2.2925
# Epoch 12/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step - accuracy: 0.9115 - loss: 0.1657 - val_accuracy: 0.7500 - val_loss: 0.8524
# Epoch 13/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - accuracy: 0.9768 - loss: 0.1207 - val_accuracy: 0.4167 - val_loss: 1.6300
# Epoch 14/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 397ms/step - accuracy: 0.8942 - loss: 0.2533 - val_accuracy: 0.6667 - val_loss: 1.4769
# Epoch 15/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - accuracy: 1.0000 - loss: 0.0609 - val_accuracy: 0.6667 - val_loss: 1.1285
# Epoch 16/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step - accuracy: 1.0000 - loss: 0.0420 - val_accuracy: 0.6667 - val_loss: 0.9350
# Epoch 17/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - accuracy: 1.0000 - loss: 0.0602 - val_accuracy: 0.7500 - val_loss: 0.6867
# Epoch 18/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - accuracy: 1.0000 - loss: 0.0244 - val_accuracy: 0.8333 - val_loss: 0.8827
# Epoch 19/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 0.8333 - val_loss: 0.7314
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step - accuracy: 0.9872 - loss: 0.0460 - val_accuracy: 0.7500 - val_loss: 0.4715
# Epoch 21/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 439ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.7500 - val_loss: 1.0095
# Epoch 22/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 401ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.7500 - val_loss: 1.8113
# Epoch 23/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step - accuracy: 0.9705 - loss: 0.0711 - val_accuracy: 0.7500 - val_loss: 0.6435
# Epoch 24/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.8333 - val_loss: 1.0888
# Epoch 25/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.9167 - val_loss: 1.2440

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image

# Loading an image you want to classify
test_image = image.load_img('C:/Users/lokes/Desktop/project/plant_detection/Dataset/single_predection/plant_tulsi.jpg', 
                            target_size=(128, 128))

test_image = image.img_to_array(test_image)

test_image = np.expand_dims(test_image, axis=0)

test_image = test_image / 255.0

result = cnn.predict(test_image)

plant_classes = training_set.class_indices

predicted_class = list(plant_classes.keys())[np.argmax(result)]

print("The predicted class is:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# The predicted class is: tulsi

# %%
cnn.save('plant_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# model.save('plant_recognition.h5')

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('plant_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
pwd
# Out:
# 'c:\\Users\\lokes\\Desktop\\project\\plant_detection'

# %%
loaded_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 50)   │         1,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 50)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 60)     │        27,060 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 60)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 54000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,912,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,941,106 (26.48 MB)
#  Trainable params: 6,941,104 (26.48 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
